# %% [markdown]
# # Optimizer Analysis
#
# Analysis-only notebook. Launch experiments with `train.py` or `sweep.py`, then load metrics here.

# %%
from pathlib import Path

from src.analysis import compare_runs

run_dirs = sorted(Path('../outputs').glob('optimizer_sweep_*'))
compare_runs(run_dirs, metric='val/loss') if run_dirs else 'No optimizer sweep runs yet.'

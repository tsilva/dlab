# %% [markdown]
# # Reconstruction Analysis
#
# Use this notebook to compare reconstruction artifacts from autoencoder, VAE, and VQ-VAE runs.

# %%
from pathlib import Path

run_dirs = sorted(Path('../outputs').glob('*vae*'))
run_dirs[:5]

# %% [markdown]
# # Latent Space Analysis
#
# Use this notebook to inspect saved embeddings or latent vectors exported from VAE-style experiments.

# %%
import numpy as np

from src.visualization import plot_latent_space

z = np.random.randn(256, 8)
labels = np.arange(256) % 10
plot_latent_space(z, labels)
